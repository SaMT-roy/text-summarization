# %% [markdown]
# Text summarization of an article extracted from an URL.

# %%
import numpy as np
import pandas as pd
import nltk
import re
from newspaper import Article

# %%
url = 'https://indianexpress.com/article/technology/tech-news-technology/what-is-mini-led-display-tech-and-why-is-everyone-talking-about-it-7135198/'
article = Article(url, language="en")

# %%
article.download() 
article.parse() 
article.nlp()

# %%
print("Article Title:") 
print(article.title) #prints the title of the article
print("\n") 
print("Article Text:") 
print(article.text) #prints the entire text of the article
# Out:
# Article Title:
# What is Mini-LED display tech and why is everyone talking about it?
#
#
# Article Text:
# CES 2021 hasn’t even officially begun, but we already know one tech trend that will dominate the tech conference. No, it isn’t 5G or self-driving tech but mini-LED displays that will be seen across swanky TVs this year. LG to TCL, every major television manufacturer has plans to show off new TVs with a mini-LED display at this year’s all-digital CES. While many see mini-LED as an emerging TV tech, some estimate that mini-LED technology will eventually come to mainstream laptops, tablets and even smartphones. But what is the brand new mini-LED tech and why are companies want to replace OLED displays with this futuristic display tech?
#
# What is Mini-LED display technology?
#
# Let’s get straight to the point. The micro-LED display is an improved version of LCD technology. Most modern LCD TVs use LEDs, or Light Emitting Diodes for their backlights. Mini LED, which is sometimes referred to as a sub-millimeter light-emitting diode, is a better version of the traditional LCD display.
#
# Mini LEDs work similarly to LEDs used in LED TVs or QLED TVs but are much smaller. At about 200 microns or 0.008 inches across, mini-LEDs are about a fifth of the size of the standard LEDs in use in LCD panels. Since they are smaller in size, more of them can be packed into a screen In fact, they provide much better control of the backlighting and this leads to better image quality.
#
# But makes mini-LED display technology so interesting is that you get the same level of contrast and brightness similar to OLED. Having a backlit means, Mini LED-capable TVs can deliver greater brightness and deeper blacks but at a much lower price. Think of mini-LED tech as an affordable version of OLED, without screen burn-in issues.
#
# MSI’s Creator 17 is the only Mini LED laptop you can buy in the market. (Image credit: MSI) MSI’s Creator 17 is the only Mini LED laptop you can buy in the market. (Image credit: MSI)
#
# Advantages of mini-LEDs over OLEDs
#
# *Greater contrast and improved black levels than OLEDs.
#
# *TV manufacturers get more control over dimming zones, meaning how bright or dim parts of the screen can go.
#
# *Less expensive to make than OLEDs.
#
# *Mini LED tech is better at displaying HDR content.
#
# Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast. (Image credit: TCL) Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast. (Image credit: TCL)
#
# Which TV brands plan to launch Mini-LED TVs?
#
# Since last year, TCL has been selling Mini-LED TVs in the market. In fact, TCL was the first major TV manufacturer to launch mini-LED TVs. At CES 2021, the Chinese company said it plans to launch a new range of TVs with the next-gen Mini-LED technology. LG meanwhile says its QNED TVs will use Mini-LED backlight technology and the new range will be shown off for the first time at the tech show. Samsung hasn’t announced any mini-LED TVs yet, but we expect the South Korean major to be a big proponent of this display tech in the future.
#
# Several Apple products to feature mini-LED displays this year
#
# But while mini-LED on TVs or laptops hasn’t exploded yet, the technology might get a big boost once Apple starts to adopt this display tech. TF International analyst Ming-Chi Kuo believes that several Apple products will launch with mini-LED display tech in 2021. Kou says mini-LED displays could come to the high-end iPad Pro and the MacBook Pro this year. In fact, Apple is rumoured to be working on as many as six devices with the new display tech. What does this mean for people who buy the new iPad Pro or MacBook Pro? Well, we have to wait for Apple to release these products first.

# %% [markdown]
# Break down the text into sentences.

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(article.text)

# %%
sentences
# Out:
# ['CES 2021 hasn’t even officially begun, but we already know one tech trend that will dominate the tech conference.',
#  'No, it isn’t 5G or self-driving tech but mini-LED displays that will be seen across swanky TVs this year.',
#  'LG to TCL, every major television manufacturer has plans to show off new TVs with a mini-LED display at this year’s all-digital CES.',
#  'While many see mini-LED as an emerging TV tech, some estimate that mini-LED technology will eventually come to mainstream laptops, tablets and even smartphones.',
#  'But what is the brand new mini-LED tech and why are companies want to replace OLED displays with this futuristic display tech?',
#  'What is Mini-LED display technology?',
#  'Let’s get straight to the point.',
#  'The micro-LED display is an improved version of LCD technology.',
#  'Most modern LCD TVs use LEDs, or Light Emitting Diodes for their backlights.',
#  'Mini LED, which is sometimes referred to as a sub-millimeter light-emitting diode, is a better version of the traditional LCD display.',
#  'Mini LEDs work similarly to LEDs used in LED TVs or QLED TVs but are much smaller.',
#  'At about 200 microns or 0.008 inches across, mini-LEDs are about a fifth of the size of the standard LEDs in use in LCD panels.',
#  'Since they are smaller in size, more of them can be packed into a screen In fact, they provide much better control of the backlighting and this leads to better image quality.',
#  'But makes mini-LED display technology so interesting is that you get the same level of contrast and brightness similar to OLED.',
#  'Having a backlit means, Mini LED-capable TVs can deliver greater brightness and deeper blacks but at a much lower price.',
#  'Think of mini-LED tech as an affordable version of OLED, without screen burn-in issues.',
#  'MSI’s Creator 17 is the only Mini LED laptop you can buy in the market.',
#  '(Image credit: MSI) MSI’s Creator 17 is the only Mini LED laptop you can buy in the market.',
#  '(Image credit: MSI)\n\nAdvantages of mini-LEDs over OLEDs\n\n*Greater contrast and improved black levels than OLEDs.',
#  '*TV manufacturers get more control over dimming zones, meaning how bright or dim parts of the screen can go.',
#  '*Less expensive to make than OLEDs.',
#  '*Mini LED tech is better at displaying HDR content.',
#  'Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast.',
#  '(Image credit: TCL) Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast.',
#  '(Image credit: TCL)\n\nWhich TV brands plan to launch Mini-LED TVs?',
#  'Since last year, TCL has been selling Mini-LED TVs in the market.',
#  'In fact, TCL was the first major TV manufacturer to launch mini-LED TVs.',
#  'At CES 2021, the Chinese company said it plans to launch a new range of TVs with the next-gen Mini-LED technology.',
#  'LG meanwhile says its QNED TVs will use Mini-LED backlight technology and the new range will be shown off for the first time at the tech show.',
#  'Samsung hasn’t announced any mini-LED TVs yet, but we expect the South Korean major to be a big proponent of this display tech in the future.',
#  'Several Apple products to feature mini-LED displays this year\n\nBut while mini-LED on TVs or laptops hasn’t exploded yet, the technology might get a big boost once Apple starts to adopt this display tech.',
#  'TF International analyst Ming-Chi Kuo believes that several Apple products will launch with mini-LED display tech in 2021.',
#  'Kou says mini-LED displays could come to the high-end iPad Pro and the MacBook Pro this year.',
#  'In fact, Apple is rumoured to be working on as many as six devices with the new display tech.',
#  'What does this mean for people who buy the new iPad Pro or MacBook Pro?',
#  'Well, we have to wait for Apple to release these products first.']

# %% [markdown]
# Sentence cleaning and transformation

# %%
from nltk.corpus import stopwords

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z0-9]',' ',sentences[i])
    review = review.lower()
    review = review.split()
    review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['ce 2021 even officially begun already know one tech trend dominate tech conference',
#  '5g self driving tech mini led display seen across swanky tv year',
#  'lg tcl every major television manufacturer plan show new tv mini led display year digital ce',
#  'many see mini led emerging tv tech estimate mini led technology eventually come mainstream laptop tablet even smartphones',
#  'brand new mini led tech company want replace oled display futuristic display tech',
#  'mini led display technology',
#  'let get straight point',
#  'micro led display improved version lcd technology',
#  'modern lcd tv use led light emitting diode backlights',
#  'mini led sometimes referred sub millimeter light emitting diode better version traditional lcd display',
#  'mini led work similarly led used led tv qled tv much smaller',
#  '200 micron 0 008 inch across mini led fifth size standard led use lcd panel',
#  'since smaller size packed screen fact provide much better control backlighting lead better image quality',
#  'make mini led display technology interesting get level contrast brightness similar oled',
#  'backlit mean mini led capable tv deliver greater brightness deeper black much lower price',
#  'think mini led tech affordable version oled without screen burn issue',
#  'msi creator 17 mini led laptop buy market',
#  'image credit msi msi creator 17 mini led laptop buy market',
#  'image credit msi advantage mini led oled greater contrast improved black level oled',
#  'tv manufacturer get control dimming zone meaning bright dim part screen go',
#  'le expensive make oled',
#  'mini led tech better displaying hdr content',
#  'mini led tech offer similar benefit oled like deeper black higher contrast',
#  'image credit tcl mini led tech offer similar benefit oled like deeper black higher contrast',
#  'image credit tcl tv brand plan launch mini led tv',
#  'since last year tcl selling mini led tv market',
#  'fact tcl first major tv manufacturer launch mini led tv',
#  'ce 2021 chinese company said plan launch new range tv next gen mini led technology',
#  'lg meanwhile say qned tv use mini led backlight technology new range shown first time tech show',
#  'samsung announced mini led tv yet expect south korean major big proponent display tech future',
#  'several apple product feature mini led display year mini led tv laptop exploded yet technology might get big boost apple start adopt display tech',
#  'tf international analyst ming chi kuo belief several apple product launch mini led display tech 2021',
#  'kou say mini led display could come high end ipad pro macbook pro year',
#  'fact apple rumoured working many six device new display tech',
#  'mean people buy new ipad pro macbook pro',
#  'well wait apple release product first']

# %%
len(corpus)
# Out:
# 36

# %%
for word in corpus:
     for i in nltk.word_tokenize(word):
            print(i)
# Out:
# ce
# 2021
# even
# officially
# begun
# already
# know
# one
# tech
# trend
# dominate
# tech
# conference
# 5g
# self
# driving
# tech
# mini
# led
# display
# seen
# across
# swanky
# tv
# year
# lg
# tcl
# every
# major
# television
# manufacturer
# plan
# show
# new
# tv
# mini
# led
# display
# year
# digital
# ce
# many
# see
# mini
# led
# emerging
# tv
# tech
# estimate
# mini
# led
# technology
# eventually
# come
# mainstream
# laptop
# tablet
# even
# smartphones
# brand
# new
# mini
# led
# tech
# company
# want
# replace
# oled
# display
# futuristic
# display
# tech
# mini
# led
# display
# technology
# let
# get
# straight
# point
# micro
# led
# display
# improved
# version
# lcd
# technology
# modern
# lcd
# tv
# use
# led
# light
# emitting
# diode
# backlights
# mini
# led
# sometimes
# referred
# sub
# millimeter
# light
# emitting
# diode
# better
# version
# traditional
# lcd
# display
# mini
# led
# work
# similarly
# led
# used
# led
# tv
# qled
# tv
# much
# smaller
# 200
# micron
# 0
# 008
# inch
# across
# mini
# led
# fifth
# size
# standard
# led
# use
# lcd
# panel
# since
# smaller
# size
# packed
# screen
# fact
# provide
# much
# better
# control
# backlighting
# lead
# better
# image
# quality
# make
# mini
# led
# display
# technology
# interesting
# get
# level
# contrast
# brightness
# similar
# oled
# backlit
# mean
# mini
# led
# capable
# tv
# deliver
# greater
# brightness
# deeper
# black
# much
# lower
# price
# think
# mini
# led
# tech
# affordable
# version
# oled
# without
# screen
# burn
# issue
# msi
# creator
# 17
# mini
# led
# laptop
# buy
# market
# image
# credit
# msi
# msi
# creator
# 17
# mini
# led
# laptop
# buy
# market
# image
# credit
# msi
# advantage
# mini
# led
# oled
# greater
# contrast
# improved
# black
# level
# oled
# tv
# manufacturer
# get
# control
# dimming
# zone
# meaning
# bright
# dim
# part
# screen
# go
# le
# expensive
# make
# oled
# mini
# led
# tech
# better
# displaying
# hdr
# content
# mini
# led
# tech
# offer
# similar
# benefit
# oled
# like
# deeper
# black
# higher
# contrast
# image
# credit
# tcl
# mini
# led
# tech
# offer
# similar
# benefit
# oled
# like
# deeper
# black
# higher
# contrast
# image
# credit
# tcl
# tv
# brand
# plan
# launch
# mini
# led
# tv
# since
# last
# year
# tcl
# selling
# mini
# led
# tv
# market
# fact
# tcl
# first
# major
# tv
# manufacturer
# launch
# mini
# led
# tv
# ce
# 2021
# chinese
# company
# said
# plan
# launch
# new
# range
# tv
# next
# gen
# mini
# led
# technology
# lg
# meanwhile
# say
# qned
# tv
# use
# mini
# led
# backlight
# technology
# new
# range
# shown
# first
# time
# tech
# show
# samsung
# announced
# mini
# led
# tv
# yet
# expect
# south
# korean
# major
# big
# proponent
# display
# tech
# future
# several
# apple
# product
# feature
# mini
# led
# display
# year
# mini
# led
# tv
# laptop
# exploded
# yet
# technology
# might
# get
# big
# boost
# apple
# start
# adopt
# display
# tech
# tf
# international
# analyst
# ming
# chi
# kuo
# belief
# several
# apple
# product
# launch
# mini
# led
# display
# tech
# 2021
# kou
# say
# mini
# led
# display
# could
# come
# high
# end
# ipad
# pro
# macbook
# pro
# year
# fact
# apple
# rumoured
# working
# many
# six
# device
# new
# display
# tech
# mean
# people
# buy
# new
# ipad
# pro
# macbook
# pro
# well
# wait
# apple
# release
# product
# first

# %% [markdown]
# Create a dictionary of count values of each word.

# %%
word_frequencies = {}

for word in corpus:
     for i in nltk.word_tokenize(word):
            if i not in word_frequencies.keys():
                word_frequencies[i] = 1
            else:
                word_frequencies[i] += 1

# %%
word_frequencies
# Out:
# {'ce': 3,
#  '2021': 3,
#  'even': 2,
#  'officially': 1,
#  'begun': 1,
#  'already': 1,
#  'know': 1,
#  'one': 1,
#  'tech': 15,
#  'trend': 1,
#  'dominate': 1,
#  'conference': 1,
#  '5g': 1,
#  'self': 1,
#  'driving': 1,
#  'mini': 28,
#  'led': 33,
#  'display': 14,
#  'seen': 1,
#  'across': 2,
#  'swanky': 1,
#  'tv': 17,
#  'year': 5,
#  'lg': 2,
#  'tcl': 5,
#  'every': 1,
#  'major': 3,
#  'television': 1,
#  'manufacturer': 3,
#  'plan': 3,
#  'show': 2,
#  'new': 6,
#  'digital': 1,
#  'many': 2,
#  'see': 1,
#  'emerging': 1,
#  'estimate': 1,
#  'technology': 7,
#  'eventually': 1,
#  'come': 2,
#  'mainstream': 1,
#  'laptop': 4,
#  'tablet': 1,
#  'smartphones': 1,
#  'brand': 2,
#  'company': 2,
#  'want': 1,
#  'replace': 1,
#  'oled': 8,
#  'futuristic': 1,
#  'let': 1,
#  'get': 4,
#  'straight': 1,
#  'point': 1,
#  'micro': 1,
#  'improved': 2,
#  'version': 3,
#  'lcd': 4,
#  'modern': 1,
#  'use': 3,
#  'light': 2,
#  'emitting': 2,
#  'diode': 2,
#  'backlights': 1,
#  'sometimes': 1,
#  'referred': 1,
#  'sub': 1,
#  'millimeter': 1,
#  'better': 4,
#  'traditional': 1,
#  'work': 1,
#  'similarly': 1,
#  'used': 1,
#  'qled': 1,
#  'much': 3,
#  'smaller': 2,
#  '200': 1,
#  'micron': 1,
#  '0': 1,
#  '008': 1,
#  'inch': 1,
#  'fifth': 1,
#  'size': 2,
#  'standard': 1,
#  'panel': 1,
#  'since': 2,
#  'packed': 1,
#  'screen': 3,
#  'fact': 3,
#  'provide': 1,
#  'control': 2,
#  'backlighting': 1,
#  'lead': 1,
#  'image': 5,
#  'quality': 1,
#  'make': 2,
#  'interesting': 1,
#  'level': 2,
#  'contrast': 4,
#  'brightness': 2,
#  'similar': 3,
#  'backlit': 1,
#  'mean': 2,
#  'capable': 1,
#  'deliver': 1,
#  'greater': 2,
#  'deeper': 3,
#  'black': 4,
#  'lower': 1,
#  'price': 1,
#  'think': 1,
#  'affordable': 1,
#  'without': 1,
#  'burn': 1,
#  'issue': 1,
#  'msi': 4,
#  'creator': 2,
#  '17': 2,
#  'buy': 3,
#  'market': 3,
#  'credit': 4,
#  'advantage': 1,
#  'dimming': 1,
#  'zone': 1,
#  'meaning': 1,
#  'bright': 1,
#  'dim': 1,
#  'part': 1,
#  'go': 1,
#  'le': 1,
#  'expensive': 1,
#  'displaying': 1,
#  'hdr': 1,
#  'content': 1,
#  'offer': 2,
#  'benefit': 2,
#  'like': 2,
#  'higher': 2,
#  'launch': 4,
#  'last': 1,
#  'selling': 1,
#  'first': 3,
#  'chinese': 1,
#  'said': 1,
#  'range': 2,
#  'next': 1,
#  'gen': 1,
#  'meanwhile': 1,
#  'say': 2,
#  'qned': 1,
#  'backlight': 1,
#  'shown': 1,
#  'time': 1,
#  'samsung': 1,
#  'announced': 1,
#  'yet': 2,
#  'expect': 1,
#  'south': 1,
#  'korean': 1,
#  'big': 2,
#  'proponent': 1,
#  'future': 1,
#  'several': 2,
#  'apple': 5,
#  'product': 3,
#  'feature': 1,
#  'exploded': 1,
#  'might': 1,
#  'boost': 1,
#  'start': 1,
#  'adopt': 1,
#  'tf': 1,
#  'international': 1,
#  'analyst': 1,
#  'ming': 1,
#  'chi': 1,
#  'kuo': 1,
#  'belief': 1,
#  'kou': 1,
#  'could': 1,
#  'high': 1,
#  'end': 1,
#  'ipad': 2,
#  'pro': 4,
#  'macbook': 2,
#  'rumoured': 1,
#  'working': 1,
#  'six': 1,
#  'device': 1,
#  'people': 1,
#  'well': 1,
#  'wait': 1,
#  'release': 1}

# %% [markdown]
# To find the weighted frequency, divide the frequency of the word by the frequency of the most occurring word.

# %%
maximum_frequncy = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)

# %%
word_frequencies
# Out:
# {'ce': 0.09090909090909091,
#  '2021': 0.09090909090909091,
#  'even': 0.06060606060606061,
#  'officially': 0.030303030303030304,
#  'begun': 0.030303030303030304,
#  'already': 0.030303030303030304,
#  'know': 0.030303030303030304,
#  'one': 0.030303030303030304,
#  'tech': 0.45454545454545453,
#  'trend': 0.030303030303030304,
#  'dominate': 0.030303030303030304,
#  'conference': 0.030303030303030304,
#  '5g': 0.030303030303030304,
#  'self': 0.030303030303030304,
#  'driving': 0.030303030303030304,
#  'mini': 0.8484848484848485,
#  'led': 1.0,
#  'display': 0.42424242424242425,
#  'seen': 0.030303030303030304,
#  'across': 0.06060606060606061,
#  'swanky': 0.030303030303030304,
#  'tv': 0.5151515151515151,
#  'year': 0.15151515151515152,
#  'lg': 0.06060606060606061,
#  'tcl': 0.15151515151515152,
#  'every': 0.030303030303030304,
#  'major': 0.09090909090909091,
#  'television': 0.030303030303030304,
#  'manufacturer': 0.09090909090909091,
#  'plan': 0.09090909090909091,
#  'show': 0.06060606060606061,
#  'new': 0.18181818181818182,
#  'digital': 0.030303030303030304,
#  'many': 0.06060606060606061,
#  'see': 0.030303030303030304,
#  'emerging': 0.030303030303030304,
#  'estimate': 0.030303030303030304,
#  'technology': 0.21212121212121213,
#  'eventually': 0.030303030303030304,
#  'come': 0.06060606060606061,
#  'mainstream': 0.030303030303030304,
#  'laptop': 0.12121212121212122,
#  'tablet': 0.030303030303030304,
#  'smartphones': 0.030303030303030304,
#  'brand': 0.06060606060606061,
#  'company': 0.06060606060606061,
#  'want': 0.030303030303030304,
#  'replace': 0.030303030303030304,
#  'oled': 0.24242424242424243,
#  'futuristic': 0.030303030303030304,
#  'let': 0.030303030303030304,
#  'get': 0.12121212121212122,
#  'straight': 0.030303030303030304,
#  'point': 0.030303030303030304,
#  'micro': 0.030303030303030304,
#  'improved': 0.06060606060606061,
#  'version': 0.09090909090909091,
#  'lcd': 0.12121212121212122,
#  'modern': 0.030303030303030304,
#  'use': 0.09090909090909091,
#  'light': 0.06060606060606061,
#  'emitting': 0.06060606060606061,
#  'diode': 0.06060606060606061,
#  'backlights': 0.030303030303030304,
#  'sometimes': 0.030303030303030304,
#  'referred': 0.030303030303030304,
#  'sub': 0.030303030303030304,
#  'millimeter': 0.030303030303030304,
#  'better': 0.12121212121212122,
#  'traditional': 0.030303030303030304,
#  'work': 0.030303030303030304,
#  'similarly': 0.030303030303030304,
#  'used': 0.030303030303030304,
#  'qled': 0.030303030303030304,
#  'much': 0.09090909090909091,
#  'smaller': 0.06060606060606061,
#  '200': 0.030303030303030304,
#  'micron': 0.030303030303030304,
#  '0': 0.030303030303030304,
#  '008': 0.030303030303030304,
#  'inch': 0.030303030303030304,
#  'fifth': 0.030303030303030304,
#  'size': 0.06060606060606061,
#  'standard': 0.030303030303030304,
#  'panel': 0.030303030303030304,
#  'since': 0.06060606060606061,
#  'packed': 0.030303030303030304,
#  'screen': 0.09090909090909091,
#  'fact': 0.09090909090909091,
#  'provide': 0.030303030303030304,
#  'control': 0.06060606060606061,
#  'backlighting': 0.030303030303030304,
#  'lead': 0.030303030303030304,
#  'image': 0.15151515151515152,
#  'quality': 0.030303030303030304,
#  'make': 0.06060606060606061,
#  'interesting': 0.030303030303030304,
#  'level': 0.06060606060606061,
#  'contrast': 0.12121212121212122,
#  'brightness': 0.06060606060606061,
#  'similar': 0.09090909090909091,
#  'backlit': 0.030303030303030304,
#  'mean': 0.06060606060606061,
#  'capable': 0.030303030303030304,
#  'deliver': 0.030303030303030304,
#  'greater': 0.06060606060606061,
#  'deeper': 0.09090909090909091,
#  'black': 0.12121212121212122,
#  'lower': 0.030303030303030304,
#  'price': 0.030303030303030304,
#  'think': 0.030303030303030304,
#  'affordable': 0.030303030303030304,
#  'without': 0.030303030303030304,
#  'burn': 0.030303030303030304,
#  'issue': 0.030303030303030304,
#  'msi': 0.12121212121212122,
#  'creator': 0.06060606060606061,
#  '17': 0.06060606060606061,
#  'buy': 0.09090909090909091,
#  'market': 0.09090909090909091,
#  'credit': 0.12121212121212122,
#  'advantage': 0.030303030303030304,
#  'dimming': 0.030303030303030304,
#  'zone': 0.030303030303030304,
#  'meaning': 0.030303030303030304,
#  'bright': 0.030303030303030304,
#  'dim': 0.030303030303030304,
#  'part': 0.030303030303030304,
#  'go': 0.030303030303030304,
#  'le': 0.030303030303030304,
#  'expensive': 0.030303030303030304,
#  'displaying': 0.030303030303030304,
#  'hdr': 0.030303030303030304,
#  'content': 0.030303030303030304,
#  'offer': 0.06060606060606061,
#  'benefit': 0.06060606060606061,
#  'like': 0.06060606060606061,
#  'higher': 0.06060606060606061,
#  'launch': 0.12121212121212122,
#  'last': 0.030303030303030304,
#  'selling': 0.030303030303030304,
#  'first': 0.09090909090909091,
#  'chinese': 0.030303030303030304,
#  'said': 0.030303030303030304,
#  'range': 0.06060606060606061,
#  'next': 0.030303030303030304,
#  'gen': 0.030303030303030304,
#  'meanwhile': 0.030303030303030304,
#  'say': 0.06060606060606061,
#  'qned': 0.030303030303030304,
#  'backlight': 0.030303030303030304,
#  'shown': 0.030303030303030304,
#  'time': 0.030303030303030304,
#  'samsung': 0.030303030303030304,
#  'announced': 0.030303030303030304,
#  'yet': 0.06060606060606061,
#  'expect': 0.030303030303030304,
#  'south': 0.030303030303030304,
#  'korean': 0.030303030303030304,
#  'big': 0.06060606060606061,
#  'proponent': 0.030303030303030304,
#  'future': 0.030303030303030304,
#  'several': 0.06060606060606061,
#  'apple': 0.15151515151515152,
#  'product': 0.09090909090909091,
#  'feature': 0.030303030303030304,
#  'exploded': 0.030303030303030304,
#  'might': 0.030303030303030304,
#  'boost': 0.030303030303030304,
#  'start': 0.030303030303030304,
#  'adopt': 0.030303030303030304,
#  'tf': 0.030303030303030304,
#  'international': 0.030303030303030304,
#  'analyst': 0.030303030303030304,
#  'ming': 0.030303030303030304,
#  'chi': 0.030303030303030304,
#  'kuo': 0.030303030303030304,
#  'belief': 0.030303030303030304,
#  'kou': 0.030303030303030304,
#  'could': 0.030303030303030304,
#  'high': 0.030303030303030304,
#  'end': 0.030303030303030304,
#  'ipad': 0.06060606060606061,
#  'pro': 0.12121212121212122,
#  'macbook': 0.06060606060606061,
#  'rumoured': 0.030303030303030304,
#  'working': 0.030303030303030304,
#  'six': 0.030303030303030304,
#  'device': 0.030303030303030304,
#  'people': 0.030303030303030304,
#  'well': 0.030303030303030304,
#  'wait': 0.030303030303030304,
#  'release': 0.030303030303030304}

# %% [markdown]
# Create a dictionary of weighted values of each sentence.

# %%
sentence_scores = {}
for sent in sentences:
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
sentence_scores
# Out:
# {'CES 2021 hasn’t even officially begun, but we already know one tech trend that will dominate the tech conference.': 1.303030303030303,
#  'No, it isn’t 5G or self-driving tech but mini-LED displays that will be seen across swanky TVs this year.': 0.7575757575757575,
#  'LG to TCL, every major television manufacturer has plans to show off new TVs with a mini-LED display at this year’s all-digital CES.': 1.272727272727273,
#  'While many see mini-LED as an emerging TV tech, some estimate that mini-LED technology will eventually come to mainstream laptops, tablets and even smartphones.': 1.5454545454545452,
#  'But what is the brand new mini-LED tech and why are companies want to replace OLED displays with this futuristic display tech?': 1.9090909090909092,
#  'What is Mini-LED display technology?': 0.6363636363636364,
#  'Let’s get straight to the point.': 0.21212121212121213,
#  'The micro-LED display is an improved version of LCD technology.': 0.9090909090909092,
#  'Most modern LCD TVs use LEDs, or Light Emitting Diodes for their backlights.': 0.3939393939393939,
#  'Mini LED, which is sometimes referred to as a sub-millimeter light-emitting diode, is a better version of the traditional LCD display.': 2.7575757575757573,
#  'Mini LEDs work similarly to LEDs used in LED TVs or QLED TVs but are much smaller.': 2.121212121212121,
#  'At about 200 microns or 0.008 inches across, mini-LEDs are about a fifth of the size of the standard LEDs in use in LCD panels.': 0.42424242424242425,
#  'But makes mini-LED display technology so interesting is that you get the same level of contrast and brightness similar to OLED.': 1.3636363636363635,
#  'Having a backlit means, Mini LED-capable TVs can deliver greater brightness and deeper blacks but at a much lower price.': 1.2727272727272725,
#  'Think of mini-LED tech as an affordable version of OLED, without screen burn-in issues.': 0.9696969696969697,
#  'MSI’s Creator 17 is the only Mini LED laptop you can buy in the market.': 2.3939393939393936,
#  '(Image credit: MSI) MSI’s Creator 17 is the only Mini LED laptop you can buy in the market.': 2.7878787878787876,
#  '(Image credit: MSI)\n\nAdvantages of mini-LEDs over OLEDs\n\n*Greater contrast and improved black levels than OLEDs.': 0.7575757575757575,
#  '*TV manufacturers get more control over dimming zones, meaning how bright or dim parts of the screen can go.': 0.9393939393939393,
#  '*Less expensive to make than OLEDs.': 0.09090909090909091,
#  '*Mini LED tech is better at displaying HDR content.': 2.515151515151515,
#  'Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast.': 2.9696969696969697,
#  '(Image credit: TCL) Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast.': 3.3939393939393936,
#  '(Image credit: TCL)\n\nWhich TV brands plan to launch Mini-LED TVs?': 1.1515151515151514,
#  'Since last year, TCL has been selling Mini-LED TVs in the market.': 0.5151515151515151,
#  'In fact, TCL was the first major TV manufacturer to launch mini-LED TVs.': 1.1515151515151514,
#  'At CES 2021, the Chinese company said it plans to launch a new range of TVs with the next-gen Mini-LED technology.': 0.7878787878787878,
#  'LG meanwhile says its QNED TVs will use Mini-LED backlight technology and the new range will be shown off for the first time at the tech show.': 1.3636363636363635,
#  'Samsung hasn’t announced any mini-LED TVs yet, but we expect the South Korean major to be a big proponent of this display tech in the future.': 1.303030303030303,
#  'TF International analyst Ming-Chi Kuo believes that several Apple products will launch with mini-LED display tech in 2021.': 1.4242424242424243,
#  'Kou says mini-LED displays could come to the high-end iPad Pro and the MacBook Pro this year.': 0.6363636363636364,
#  'In fact, Apple is rumoured to be working on as many as six devices with the new display tech.': 1.4545454545454546,
#  'What does this mean for people who buy the new iPad Pro or MacBook Pro?': 0.7272727272727272,
#  'Well, we have to wait for Apple to release these products first.': 0.33333333333333337}

# %% [markdown]
# Now order each sentence based on their values.
#
# We will get our text summarization.

# %%
import heapq
summary_sentences = heapq.nlargest(20, sentence_scores, key=sentence_scores.get)

for i in summary_sentences:
    print(i)
    print(' ')
# Out:
# (Image credit: TCL) Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast.
#
# Mini LED tech offers similar benefits to OLED, like deeper blacks and higher contrast.
#
# (Image credit: MSI) MSI’s Creator 17 is the only Mini LED laptop you can buy in the market.
#
# Mini LED, which is sometimes referred to as a sub-millimeter light-emitting diode, is a better version of the traditional LCD display.
#
# *Mini LED tech is better at displaying HDR content.
#
# MSI’s Creator 17 is the only Mini LED laptop you can buy in the market.
#
# Mini LEDs work similarly to LEDs used in LED TVs or QLED TVs but are much smaller.
#
# But what is the brand new mini-LED tech and why are companies want to replace OLED displays with this futuristic display tech?
#
# While many see mini-LED as an emerging TV tech, some estimate that mini-LED technology will eventually come to mainstream laptops, tablets and even smartphones.
#
# In fact, Apple is rumoured to be working on as many as six devices with the new display tech.
#
# TF International analyst Ming-Chi Kuo believes that several Apple products will launch with mini-LED display tech in 2021.
#
# But makes mini-LED display technology so interesting is that you get the same level of contrast and brightness similar to OLED.
#
# LG meanwhile says its QNED TVs will use Mini-LED backlight technology and the new range will be shown off for the first time at the tech show.
#
# CES 2021 hasn’t even officially begun, but we already know one tech trend that will dominate the tech conference.
#
# Samsung hasn’t announced any mini-LED TVs yet, but we expect the South Korean major to be a big proponent of this display tech in the future.
#
# LG to TCL, every major television manufacturer has plans to show off new TVs with a mini-LED display at this year’s all-digital CES.
#
# Having a backlit means, Mini LED-capable TVs can deliver greater brightness and deeper blacks but at a much lower price.
#
# (Image credit: TCL)
#
# Which TV brands plan to launch Mini-LED TVs?
#
# In fact, TCL was the first major TV manufacturer to launch mini-LED TVs.
#
# Think of mini-LED tech as an affordable version of OLED, without screen burn-in issues.
